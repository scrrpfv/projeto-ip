# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import nbformat
from multidata import *

# %%
# %run ../Limpezas/limpeza_oferta_demanda.ipynb
# %run ../Limpezas/limpeza_análise_energética.ipynb
# %run ../Limpezas/limpeza_socioeconomia.ipynb

# %%
eletr = dict_oferta_demanda['Eletricidade']
prima = dict_analise_energetica['Produção_de_Energia_Primária']
oftin = dict_analise_energetica['Oferta_Interna_de_Energia']

# %%
e = MultiData(dict_analise_energetica)
print(e)
e.autoplot(14, n=10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\Users\afp2\projeto-ip\Analises\testes.ipynb Cell 4 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/Users/afp2/projeto-ip/Analises/testes.ipynb#Y132sZmlsZQ%3D%3D?line=0'>1</a> e = MultiData(dict_analise_energetica)
#       <a href='vscode-notebook-cell:/d%3A/Users/afp2/projeto-ip/Analises/testes.ipynb#Y132sZmlsZQ%3D%3D?line=1'>2</a> print(e)
#       <a href='vscode-notebook-cell:/d%3A/Users/afp2/projeto-ip/Analises/testes.ipynb#Y132sZmlsZQ%3D%3D?line=2'>3</a> e.autoplot(14, n=10)
#
# File d:\Users\afp2\projeto-ip\Analises\multidata.py:15, in MultiData.__init__(self, datadict)
#      13 self.names = [df for df in datadict]
#      14 for name in self.names:
# ---> 15     self.datas[name] = DataTable(df=self.datas[name], name=name)
#      16 self.Projection = Projection(self)
#
# File d:\Users\afp2\projeto-ip\Analises\multidata.py:132, in DataTable.__init__(self, df, name, last_year, **kwargs)
#     130 def __init__(self, df=pd.DataFrame(), name='Noname', last_year=2023, **kwargs):
#     131     super().__init__(**kwargs)
# --> 132     self.columns = df.columns
#     133     self.data = copy.deepcopy(df.values)
#     135     self.name = name
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\generic.py:6310, in NDFrame.__setattr__(self, name, value)
#    6308 try:
#    6309     object.__getattribute__(self, name)
# -> 6310     return object.__setattr__(self, name, value)
#    6311 except AttributeError:
#    6312     pass
#
# File properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\generic.py:813, in NDFrame._set_axis(self, axis, labels)
#     808 """
#     809 This is called from the cython code when we set the `index` attribute
#     810 directly, e.g. `series.index = [1, 2, 3]`.
#     811 """
#     812 labels = ensure_index(labels)
# --> 813 self._mgr.set_axis(axis, labels)
#     814 self._clear_item_cache()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\internals\managers.py:238, in BaseBlockManager.set_axis(self, axis, new_labels)
#     236 def set_axis(self, axis: AxisInt, new_labels: Index) -> None:
#     237     # Caller is responsible for ensuring we have an Index object.
# --> 238     self._validate_set_axis(axis, new_labels)
#     239     self.axes[axis] = new_labels
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\internals\base.py:98, in DataManager._validate_set_axis(self, axis, new_labels)
#      95     pass
#      97 elif new_len != old_len:
# ---> 98     raise ValueError(
#      99         f"Length mismatch: Expected axis has {old_len} elements, new "
#     100         f"values have {new_len} elements"
#     101     )
#
# ValueError: Length mismatch: Expected axis has 0 elements, new values have 15 elements

# %%
e.autoplot(0)

# %%
e.autoplot(5)

# %%
e.autoplot(10)

# %%
e.autoplot(14)

# %%
plt.matshow(dict_oferta_demanda['Urânio'].corr())
plt.show()

# %%
A = e.Projection.VAR(last_year_projected=2000, columns=[(0, 'PETRÓLEO'), (0, 'NÃO RENOVÁVEL')])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\Users\afp2\projeto-ip\Analises\testes.ipynb Cell 10 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/Users/afp2/projeto-ip/Analises/testes.ipynb#Y141sZmlsZQ%3D%3D?line=0'>1</a> A = e.Projection.VAR(last_year_projected=2000, columns=[(0, 'PETRÓLEO'), (0, 'NÃO RENOVÁVEL')])
#
# NameError: name 'e' is not defined
