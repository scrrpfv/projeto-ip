# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Separação das diferentes tabelas dentro da oferta e demanda

# %%
dictd = {
    'Fontes_Primárias': pd.read_excel('databases/Dados EPE/Oferta e Demanda de Energia por Fonte.xlsx', header=1, usecols='A:BB', nrows=31).transpose(),
    'Petróleo': pd.read_excel('databases/Dados EPE/Oferta e Demanda de Energia por Fonte.xlsx', header=39, usecols='A:BB', nrows=7).transpose(),
    'Gás_Natural': pd.read_excel('databases/Dados EPE/Oferta e Demanda de Energia por Fonte.xlsx', header=56, usecols='A:BB', nrows=27).transpose(),
    'Carvão_Vapor': pd.read_excel('databases/Dados EPE/Oferta e Demanda de Energia por Fonte.xlsx', header=90, usecols='A:BB', nrows=22).transpose(),
    'Carvão_Metalúrgico': pd.read_excel('databases/Dados EPE/Oferta e Demanda de Energia por Fonte.xlsx', header=121, usecols='A:BB', nrows=134-122).transpose(),
    'Energia_Hidráulica': pd.read_excel('databases/Dados EPE/Oferta e Demanda de Energia por Fonte.xlsx', header=143, usecols='A:BB', nrows=148-143).transpose(),
    'Energia_Eólica': pd.read_excel('databases/Dados EPE/Oferta e Demanda de Energia por Fonte.xlsx', header=152, usecols='A:BB', nrows=2).transpose(),
    'Energia_Solar_Fotovoltaica': pd.read_excel('databases/Dados EPE/Oferta e Demanda de Energia por Fonte.xlsx', header=160, usecols='A:BB', nrows=2).transpose(),
    'Energia_Solar_Térmica': pd.read_excel('databases/Dados EPE/Oferta e Demanda de Energia por Fonte.xlsx', header=167, usecols='A:BB', nrows=174-168).transpose(),
    'Urânio': pd.read_excel('databases/Dados EPE/Oferta e Demanda de Energia por Fonte.xlsx', header=178, usecols='A:BB', nrows=184-178).transpose(),
    'Lenha': pd.read_excel('databases/Dados EPE/Oferta e Demanda de Energia por Fonte.xlsx', header=190, usecols='A:BB', nrows=216-190).transpose(),
    'Caldo_de_Cana': pd.read_excel('databases/Dados EPE/Oferta e Demanda de Energia por Fonte.xlsx', header=222, usecols='A:BB', nrows=4).transpose(),
    'Melaço': pd.read_excel('databases/Dados EPE/Oferta e Demanda de Energia por Fonte.xlsx', header=232, usecols='A:BB', nrows=4).transpose(),
    'Bagaço_de_Cana': pd.read_excel('databases/Dados EPE/Oferta e Demanda de Energia por Fonte.xlsx', header=242, usecols='A:BB', nrows=254-242).transpose(),
    'Lixívia': pd.read_excel('databases/Dados EPE/Oferta e Demanda de Energia por Fonte.xlsx', header=260, usecols='A:BB', nrows=8).transpose(),
    'Outras_Fontes_Primárias': pd.read_excel('databases/Dados EPE/Oferta e Demanda de Energia por Fonte.xlsx', header=274, usecols='A:BB', nrows=10).transpose(),
    'Total_de_Fontes_Secundárias': pd.read_excel('databases/Dados EPE/Oferta e Demanda de Energia por Fonte.xlsx', header=291, usecols='A:BB', nrows=324-291).transpose(),
    'Derivados_de_Petróleo_e_Gás_Natural': pd.read_excel('databases/Dados EPE/Oferta e Demanda de Energia por Fonte.xlsx', header=328, usecols='A:BB', nrows=361-328).transpose(),
    'Óleo_Diesel_Total': pd.read_excel('databases/Dados EPE/Oferta e Demanda de Energia por Fonte.xlsx', header=367, usecols='A:BB', nrows=394-367).transpose(),
    'Diesel_de_Petróleo': pd.read_excel('databases/Dados EPE/Oferta e Demanda de Energia por Fonte.xlsx', header=404, usecols='A:BB', nrows=431-404).transpose(),
    'Biodiesel': pd.read_excel('databases/Dados EPE/Oferta e Demanda de Energia por Fonte.xlsx', header=437, usecols='A:BB', nrows=13).transpose(),
    'Óleo_Combustível': pd.read_excel('databases/Dados EPE/Oferta e Demanda de Energia por Fonte.xlsx', header=472, usecols='A:BB', nrows=501-472).transpose(),
    'Gasolina': pd.read_excel('databases/Dados EPE/Oferta e Demanda de Energia por Fonte.xlsx', header=509, usecols='A:BB', nrows=520-509).transpose(),
    'Gás_Liquefeito_de_Petróleo': pd.read_excel('databases/Dados EPE/Oferta e Demanda de Energia por Fonte.xlsx', header=527, usecols='A:BB', nrows=551-527).transpose(),
    'Nafta': pd.read_excel('databases/Dados EPE/Oferta e Demanda de Energia por Fonte.xlsx', header=557, usecols='A:BB', nrows=571-557).transpose(),
    'Coque_de_Carvão_Mineral': pd.read_excel('databases/Dados EPE/Oferta e Demanda de Energia por Fonte.xlsx', header=579, usecols='A:BB', nrows=594-579).transpose(),
    'Querosene': pd.read_excel('databases/Dados EPE/Oferta e Demanda de Energia por Fonte.xlsx', header=598, usecols='A:BB', nrows=623-598).transpose(),
    'Gás_de_Cidade': pd.read_excel('databases/Dados EPE/Oferta e Demanda de Energia por Fonte.xlsx', header=629, usecols='A:BB', nrows=648-629).transpose(),
    'Gás_de_Coqueria': pd.read_excel('databases/Dados EPE/Oferta e Demanda de Energia por Fonte.xlsx', header=652, usecols='A:BB', nrows=662-652).transpose(),
    'Eletricidade': pd.read_excel('databases/Dados EPE/Oferta e Demanda de Energia por Fonte.xlsx', header=668, usecols='A:BB', nrows=697-668).transpose(),
    'Carvão_Vegetal': pd.read_excel('databases/Dados EPE/Oferta e Demanda de Energia por Fonte.xlsx', header=701, usecols='A:BB', nrows=723-701).transpose(),
    'Álcool_Etílico_Total': pd.read_excel('databases/Dados EPE/Oferta e Demanda de Energia por Fonte.xlsx', header=727, usecols='A:BB', nrows=739-727).transpose(),
    'Álcool_Anidro': pd.read_excel('databases/Dados EPE/Oferta e Demanda de Energia por Fonte.xlsx', header=747, usecols='A:BB', nrows=758-747).transpose(),
    'Álcool_Hidratado': pd.read_excel('databases/Dados EPE/Oferta e Demanda de Energia por Fonte.xlsx', header=762, usecols='A:BB', nrows=774-762).transpose(),
    'Outras_Secundárias_de_Petróleo': pd.read_excel('databases/Dados EPE/Oferta e Demanda de Energia por Fonte.xlsx', header=780, usecols='A:BB', nrows=800-780).transpose(),
    'Alcatrão': pd.read_excel('databases/Dados EPE/Oferta e Demanda de Energia por Fonte.xlsx', header=806, usecols='A:BB', nrows=818-807).transpose(),
    'Produtos_não_Energéticos_de_Petróleo': pd.read_excel('databases/Dados EPE/Oferta e Demanda de Energia por Fonte.xlsx', header=824, usecols='A:BB', nrows=833-824).transpose()
}

# %%
dictd['Fontes_Primárias']
# Out:
#                                    0                               1   \
# FLUXO  PRODUÇÃO                        IMPORTAÇÃO
# 1970                     49628.845701                     19298.57244
# 1971                     50473.678756                    21671.342348
# 1972                     51840.503685                    27079.821048
# 1973                     52584.852448                     36316.87752
# 1974                     55221.051605                    36367.978425
# 1975                     55554.004565                    38594.473492
# 1976                     55868.652597                     43959.86198
# 1977                     57707.216351                    44305.800296
# 1978                     58681.282093                    48434.403588
# 1979                     62107.092041                    54146.320092
# 1980                       66408.9308                     47651.01932
# 1981                     68985.259606                     46417.28766
# ...

# %%
dict = {}
for i in dictd:
    df = dictd[i]
    df.columns = pd.Series([i.strip() for i in df.iloc[0]])
    df = df[1:]
    dict[i] = df
    print(i)
    print(df.columns.values)
# Out:
# Fontes_Primárias
# ['PRODUÇÃO' 'IMPORTAÇÃO' 'EXPORTAÇÃO'
#  'VARIAÇÃO DE ESTOQUES, PERDAS E AJUSTES ¹' 'CONSUMO TOTAL'
#  'TRANSFORMAÇÃO' 'CONSUMO FINAL' 'CONSUMO FINAL NÃO-ENERGÉTICO'
#  'CONSUMO FINAL ENERGÉTICO' 'SETOR ENERGÉTICO' 'RESIDENCIAL' 'COMERCIAL'
#  'PÚBLICO' 'AGROPECUÁRIO' 'TRANSPORTES' 'RODOVIÁRIO' 'FERROVIÁRIO'
#  'HIDROVIÁRIO' 'INDUSTRIAL' 'CIMENTO' 'FERRO-GUSA E AÇO' 'FERRO-LIGAS'
#  'MINERAÇÃO E PELOTIZAÇÃO' 'NÃO-FERROSOS E OUTROS DA METALURGIA' 'QUÍMICA'
#  'ALIMENTOS E BEBIDAS' 'TÊXTIL' 'PAPEL E CELULOSE' 'CERÂMICA' 'OUTROS'
#  'CONSUMO NÃO-IDENTIFICADO']
# Petróleo
# ['PRODUÇÃO 1' 'IMPORTAÇÃO 2' 'EXPORTAÇÃO'
#  'VARIAÇÃO DE ESTOQUES, PERDAS E AJUSTES ³' 'CONSUMO TOTAL'
#  'TRANSFORMAÇÃO 2' '1 Não inclui Líquidos de Gás Natural.']
# Gás_Natural
# ['PRODUÇÃO' 'IMPORTAÇÃO' 'VARIAÇÃO DE ESTOQUES, PERDAS E AJUSTES ¹'
#  'CONSUMO TOTAL' 'TRANSFORMAÇÃO' 'PRODUÇÃO DE DERIVADOS DE PETRÓLEO'
#  'GERAÇÃO ELÉTRICA' 'CONSUMO FINAL' 'CONSUMO FINAL NÃO-ENERGÉTICO'
# ...

# %%
dict['Alcatrão']
# Out:
#         PRODUÇÃO VARIAÇÃO DE ESTOQUES, PERDAS E AJUSTES CONSUMO TOTAL  \
# 1970          70                                      0            70
# 1971          76                                      0            76
# 1972          80                                      0            80
# 1973          86                                      0            86
# 1974          82                                      0            82
# 1975         102                                      0           102
# 1976         118                                      0           118
# 1977         132                                      0           132
# 1978         157                                      0           157
# 1979         171                                      0           171
# 1980         208                                      0           208
# 1981         190                                      0           190
# ...
