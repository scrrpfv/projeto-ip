# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Separação das diferentes tabelas dentro da oferta e demanda

# %%
dictd = {
    'Fontes_Primárias': pd.read_excel('databases/Dados EPE/Oferta e Demanda de Energia por Fonte.xlsx', header=1, usecols='A:BB', nrows=31).transpose(),
    'Petróleo': pd.read_excel('databases/Dados EPE/Oferta e Demanda de Energia por Fonte.xlsx', header=39, usecols='A:BB', nrows=6).transpose(),
    'Gás_Natural': pd.read_excel('databases/Dados EPE/Oferta e Demanda de Energia por Fonte.xlsx', header=56, usecols='A:BB', nrows=27).transpose(),
    'Carvão_Vapor': pd.read_excel('databases/Dados EPE/Oferta e Demanda de Energia por Fonte.xlsx', header=90, usecols='A:BB', nrows=22).transpose(),
    'Carvão_Metalúrgico': pd.read_excel('databases/Dados EPE/Oferta e Demanda de Energia por Fonte.xlsx', header=121, usecols='A:BB', nrows=134-122).transpose(),
    'Energia_Hidráulica': pd.read_excel('databases/Dados EPE/Oferta e Demanda de Energia por Fonte.xlsx', header=143, usecols='A:BB', nrows=148-143).transpose(),
    'Energia_Eólica': pd.read_excel('databases/Dados EPE/Oferta e Demanda de Energia por Fonte.xlsx', header=152, usecols='A:BB', nrows=2).transpose(),
    'Energia_Solar_Fotovoltaica': pd.read_excel('databases/Dados EPE/Oferta e Demanda de Energia por Fonte.xlsx', header=160, usecols='A:BB', nrows=2).transpose(),
    'Energia_Solar_Térmica': pd.read_excel('databases/Dados EPE/Oferta e Demanda de Energia por Fonte.xlsx', header=167, usecols='A:BB', nrows=174-168).transpose(),
    'Urânio': pd.read_excel('databases/Dados EPE/Oferta e Demanda de Energia por Fonte.xlsx', header=178, usecols='A:BB', nrows=5).transpose(),
    'Lenha': pd.read_excel('databases/Dados EPE/Oferta e Demanda de Energia por Fonte.xlsx', header=190, usecols='A:BB', nrows=216-190-1).transpose(),
    'Caldo_de_Cana': pd.read_excel('databases/Dados EPE/Oferta e Demanda de Energia por Fonte.xlsx', header=222, usecols='A:BB', nrows=3).transpose(),
    'Melaço': pd.read_excel('databases/Dados EPE/Oferta e Demanda de Energia por Fonte.xlsx', header=232, usecols='A:BB', nrows=3).transpose(),
    'Bagaço_de_Cana': pd.read_excel('databases/Dados EPE/Oferta e Demanda de Energia por Fonte.xlsx', header=242, usecols='A:BB', nrows=254-243).transpose(),
    'Lixívia': pd.read_excel('databases/Dados EPE/Oferta e Demanda de Energia por Fonte.xlsx', header=260, usecols='A:BB', nrows=8).transpose(),
    'Outras_Fontes_Primárias': pd.read_excel('databases/Dados EPE/Oferta e Demanda de Energia por Fonte.xlsx', header=274, usecols='A:BB', nrows=9).transpose(),
    'Total_de_Fontes_Secundárias': pd.read_excel('databases/Dados EPE/Oferta e Demanda de Energia por Fonte.xlsx', header=291, usecols='A:BB', nrows=324-291).transpose(),
    'Derivados_de_Petróleo_e_Gás_Natural': pd.read_excel('databases/Dados EPE/Oferta e Demanda de Energia por Fonte.xlsx', header=328, usecols='A:BB', nrows=361-328-1).transpose(),
    'Óleo_Diesel_Total': pd.read_excel('databases/Dados EPE/Oferta e Demanda de Energia por Fonte.xlsx', header=367, usecols='A:BB', nrows=394-367-1).transpose(),
    'Diesel_de_Petróleo': pd.read_excel('databases/Dados EPE/Oferta e Demanda de Energia por Fonte.xlsx', header=404, usecols='A:BB', nrows=431-404-1).transpose(),
    'Biodiesel': pd.read_excel('databases/Dados EPE/Oferta e Demanda de Energia por Fonte.xlsx', header=437, usecols='A:BB', nrows=13).transpose(),
    'Óleo_Combustível': pd.read_excel('databases/Dados EPE/Oferta e Demanda de Energia por Fonte.xlsx', header=472, usecols='A:BB', nrows=501-472-1).transpose(),
    'Gasolina': pd.read_excel('databases/Dados EPE/Oferta e Demanda de Energia por Fonte.xlsx', header=509, usecols='A:BB', nrows=520-509-1).transpose(),
    'Gás_Liquefeito_de_Petróleo': pd.read_excel('databases/Dados EPE/Oferta e Demanda de Energia por Fonte.xlsx', header=527, usecols='A:BB', nrows=551-527-1).transpose(),
    'Nafta': pd.read_excel('databases/Dados EPE/Oferta e Demanda de Energia por Fonte.xlsx', header=557, usecols='A:BB', nrows=571-557-1).transpose(),
    'Coque_de_Carvão_Mineral': pd.read_excel('databases/Dados EPE/Oferta e Demanda de Energia por Fonte.xlsx', header=579, usecols='A:BB', nrows=594-579).transpose(),
    'Querosene': pd.read_excel('databases/Dados EPE/Oferta e Demanda de Energia por Fonte.xlsx', header=598, usecols='A:BB', nrows=623-598-1).transpose(),
    'Gás_de_Cidade': pd.read_excel('databases/Dados EPE/Oferta e Demanda de Energia por Fonte.xlsx', header=629, usecols='A:BB', nrows=648-629).transpose(),
    'Gás_de_Coqueria': pd.read_excel('databases/Dados EPE/Oferta e Demanda de Energia por Fonte.xlsx', header=652, usecols='A:BB', nrows=662-652-1).transpose(),
    'Eletricidade': pd.read_excel('databases/Dados EPE/Oferta e Demanda de Energia por Fonte.xlsx', header=668, usecols='A:BB', nrows=697-668).transpose(),
    'Carvão_Vegetal': pd.read_excel('databases/Dados EPE/Oferta e Demanda de Energia por Fonte.xlsx', header=701, usecols='A:BB', nrows=723-701).transpose(),
    'Álcool_Etílico_Total': pd.read_excel('databases/Dados EPE/Oferta e Demanda de Energia por Fonte.xlsx', header=727, usecols='A:BB', nrows=739-727-1).transpose(),
    'Álcool_Anidro': pd.read_excel('databases/Dados EPE/Oferta e Demanda de Energia por Fonte.xlsx', header=747, usecols='A:BB', nrows=758-747).transpose(),
    'Álcool_Hidratado': pd.read_excel('databases/Dados EPE/Oferta e Demanda de Energia por Fonte.xlsx', header=762, usecols='A:BB', nrows=774-762-1).transpose(),
    'Outras_Secundárias_de_Petróleo': pd.read_excel('databases/Dados EPE/Oferta e Demanda de Energia por Fonte.xlsx', header=780, usecols='A:BB', nrows=800-780-1).transpose(),
    'Alcatrão': pd.read_excel('databases/Dados EPE/Oferta e Demanda de Energia por Fonte.xlsx', header=806, usecols='A:BB', nrows=818-807).transpose(),
    'Produtos_não_Energéticos_de_Petróleo': pd.read_excel('databases/Dados EPE/Oferta e Demanda de Energia por Fonte.xlsx', header=824, usecols='A:BB', nrows=833-824-1).transpose()
}

# %%
dict = {}
for i in dictd:
    df = dictd[i]
    df.reset_index(inplace=True)
    headers = pd.Series([v.strip() for v in df.iloc[0].values])
    df.columns = headers
    df.drop(index=0, axis=0, inplace=True)
    df.rename(columns={'FLUXO': 'ANO'}, inplace=True)
    dict[i] = df
# Out:
# Index(['ANO', 'PRODUÇÃO', 'IMPORTAÇÃO', 'EXPORTAÇÃO',
#        'VARIAÇÃO DE ESTOQUES, PERDAS E AJUSTES ¹', 'CONSUMO TOTAL',
#        'TRANSFORMAÇÃO', 'CONSUMO FINAL', 'CONSUMO FINAL NÃO-ENERGÉTICO',
#        'CONSUMO FINAL ENERGÉTICO', 'SETOR ENERGÉTICO', 'RESIDENCIAL',
#        'COMERCIAL', 'PÚBLICO', 'AGROPECUÁRIO', 'TRANSPORTES', 'RODOVIÁRIO',
#        'FERROVIÁRIO', 'HIDROVIÁRIO', 'INDUSTRIAL', 'CIMENTO',
#        'FERRO-GUSA E AÇO', 'FERRO-LIGAS', 'MINERAÇÃO E PELOTIZAÇÃO',
#        'NÃO-FERROSOS E OUTROS DA METALURGIA', 'QUÍMICA', 'ALIMENTOS E BEBIDAS',
#        'TÊXTIL', 'PAPEL E CELULOSE', 'CERÂMICA', 'OUTROS',
#        'CONSUMO NÃO-IDENTIFICADO'],
#       dtype='object')
# Index(['ANO', 'PRODUÇÃO 1', 'IMPORTAÇÃO 2', 'EXPORTAÇÃO',
#        'VARIAÇÃO DE ESTOQUES, PERDAS E AJUSTES ³', 'CONSUMO TOTAL',
#        'TRANSFORMAÇÃO 2'],
#       dtype='object')
# Index(['ANO', 'PRODUÇÃO', 'IMPORTAÇÃO',
#        'VARIAÇÃO DE ESTOQUES, PERDAS E AJUSTES ¹', 'CONSUMO TOTAL',
#        'TRANSFORMAÇÃO', 'PRODUÇÃO DE DERIVADOS DE PETRÓLEO',
#        'GERAÇÃO ELÉTRICA', 'CONSUMO FINAL', 'CONSUMO FINAL NÃO-ENERGÉTICO',
#        'CONSUMO FINAL ENERGÉTICO', 'SETOR ENERGÉTICO', 'RESIDENCIAL',
#        'COMERCIAL/PÚBLICO', 'TRANSPORTES', 'RODOVIÁRIO', 'INDUSTRIAL',
#        'CIMENTO', 'FERRO-GUSA E AÇO', 'FERRO-LIGAS', 'MINERAÇÃO E PELOTIZAÇÃO',
#        'NÃO-FERROSOS E OUTROS DA METALURGIA', 'QUÍMICA', 'ALIMENTOS E BEBIDAS',
#        'TÊXTIL', 'PAPEL E CELULOSE', 'CERÂMICA', 'OUTROS'],
#       dtype='object')
# Index(['ANO', 'PRODUÇÃO', 'EXPORTAÇÃO/IMPORTAÇÃO',
#        'VARIAÇÃO DE ESTOQUES, PERDAS E AJUSTES', 'CONSUMO TOTAL',
#        'TRANSFORMAÇÃO¹', 'CONSUMO FINAL', 'CONSUMO FINAL ENERGÉTICO',
#        'TRANSPORTES', 'FERROVIÁRIO', 'INDUSTRIAL²', 'CIMENTO',
#        'FERRO-GUSA E AÇO', 'FERRO-LIGAS', 'MINERAÇÃO E PELOTIZAÇÃO',
#        'NÃO-FERROSOS E OUTROS DA METALURGIA', 'QUÍMICA', 'ALIMENTOS E BEBIDAS',
#        'TÊXTIL', 'PAPEL E CELULOSE', 'CERÂMICA', 'OUTROS',
#        'CONSUMO NÃO-IDENTIFICADO'],
#       dtype='object')
# Index(['ANO', 'PRODUÇÃO', 'IMPORTAÇÃO',
#        'VARIAÇÃO DE ESTOQUES, PERDAS E AJUSTES', 'CONSUMO TOTAL',
#        'TRANSFORMAÇÃO ¹', 'CONSUMO FINAL NA INDÚSTRIA ²', 'CIMENTO',
#        'FERRO-GUSA E AÇO', 'FERRO-LIGAS', 'MINERAÇÃO E PELOTIZAÇÃO',
#        'NÃO-FERROSOS E OUTROS DA METALURGIA', 'OUTROS NÃO ESPECIFICADOS'],
#       dtype='object')
# Index(['PRODUÇÃO', 'CONSUMO TOTAL', 'TRANSFORMAÇÃO', 'GERAÇÃO PÚBLICA',
#        'GERAÇÃO DE AUTOPRODUTORES'],
#       dtype='object')
# Index(['ANO', 'GERAÇÃO TOTAL¹', 'CONSUMO TOTAL'], dtype='object')
# Index(['ANO', 'GERAÇÃO TOTAL', 'CONSUMO TOTAL'], dtype='object')
# Index(['ANO', 'PRODUÇÃO', 'CONSUMO FINAL', 'RESIDENCIAL', 'COMERCIAL',
#        'INDUSTRIAL', 'OUTRAS INDÚSTRIAS'],
#       dtype='object')
# Index(['ANO', 'PRODUÇÃO', 'IMPORTAÇÃO',
#        'VARIAÇÃO DE ESTOQUES, PERDAS E AJUSTES', 'CONSUMO TOTAL',
#        'TRANSFORMAÇÃO1'],
#       dtype='object')
# Index(['ANO', 'PRODUÇÃO', 'IMPORTAÇÃO', 'CONSUMO TOTAL', 'TRANSFORMAÇÃO 1',
#        'GERAÇÃO ELÉTRICA', 'PRODUÇÃO DE CARVÃO VEGETAL', 'CONSUMO FINAL',
#        'CONSUMO FINAL ENERGÉTICO', 'RESIDENCIAL', 'COMERCIAL', 'PÚBLICO',
#        'AGROPECUÁRIO', 'TRANSPORTES', 'FERROVIÁRIO', 'HIDROVIÁRIO',
#        'INDUSTRIAL', 'CIMENTO', 'MINERAÇÃO E PELOTIZAÇÃO',
#        'FERRO-LIGAS  E OUTROS DA METALURGIA', 'QUÍMICA', 'ALIMENTOS E BEBIDAS',
#        'TÊXTIL', 'PAPEL E CELULOSE', 'CERÂMICA', 'OUTROS'],
#       dtype='object')
# Index(['ANO', 'PRODUÇÃO', 'CONSUMO TOTAL', 'TRANSFORMAÇÃO 1'], dtype='object')
# Index(['ANO', 'PRODUÇÃO', 'CONSUMO TOTAL', 'TRANSFORMAÇÃO 1'], dtype='object')
# Index(['ANO', 'PRODUÇÃO', 'CONSUMO TOTAL', 'TRANSFORMAÇÃO1', 'CONSUMO FINAL',
#        'CONSUMO FINAL ENERGÉTICO', 'SETOR ENERGÉTICO', 'INDUSTRIAL', 'QUÍMICA',
#        'ALIMENTOS E BEBIDAS', 'PAPEL E CELULOSE', 'OUTROS'],
#       dtype='object')
# Index(['ANO', 'PRODUÇÃO', 'CONSUMO TOTAL', 'TRANSFORMAÇÃO 1', 'CONSUMO FINAL',
#        'CONSUMO FINAL ENERGÉTICO', 'INDUSTRIAL', 'PAPEL E CELULOSE',
#        '1Geração de energia elétrica.'],
#       dtype='object')
# Index(['ANO', 'PRODUÇÃO', 'CONSUMO TOTAL', 'TRANSFORMAÇÃO 1', 'CONSUMO FINAL',
#        'CONSUMO FINAL ENERGÉTICO', 'INDUSTRIAL', 'CIMENTO', 'PAPEL E CELULOSE',
#        'OUTRAS INDÚSTRIAS'],
#       dtype='object')
# Index(['ANO', 'PRODUÇÃO', 'IMPORTAÇÃO', 'EXPORTAÇÃO',
#        'VARIAÇÃO DE ESTOQUES, PERDAS E AJUSTES', 'CONSUMO TOTAL',
#        'TRANSFORMAÇÃO', 'CONSUMO FINAL', 'CONSUMO FINAL NÃO-ENERGÉTICO',
#        'CONSUMO FINAL ENERGÉTICO', 'SETOR ENERGÉTICO', 'RESIDENCIAL',
#        'COMERCIAL', 'PÚBLICO', 'AGROPECUÁRIO', 'TRANSPORTES', 'RODOVIÁRIO',
#        'FERROVIÁRIO', 'AÉREO', 'HIDROVIÁRIO', 'INDUSTRIAL', 'CIMENTO',
#        'FERRO-GUSA E AÇO', 'FERRO-LIGAS', 'MINERAÇÃO E PELOTIZAÇÃO',
#        'NÃO-FERROSOS  E OUTROS DA METALURGIA', 'QUÍMICA',
#        'ALIMENTOS E BEBIDAS', 'TÊXTIL', 'PAPEL E CELULOSE', 'CERÂMICA',
#        'OUTROS', 'CONSUMO NÃO-IDENTIFICADO'],
#       dtype='object')
# Index(['ANO', 'PRODUÇÃO', 'IMPORTAÇÃO', 'EXPORTAÇÃO',
#        'VARIAÇÃO DE ESTOQUES, PERDAS E AJUSTES ¹', 'CONSUMO TOTAL',
#        'TRANSFORMAÇÃO', 'CONSUMO FINAL', 'CONSUMO FINAL NÃO-ENERGÉTICO',
#        'CONSUMO FINAL ENERGÉTICO', 'SETOR ENERGÉTICO', 'RESIDENCIAL',
#        'COMERCIAL', 'PÚBLICO', 'AGROPECUÁRIO', 'TRANSPORTES', 'RODOVIÁRIO',
#        'FERROVIÁRIO', 'AÉREO', 'HIDROVIÁRIO', 'INDUSTRIAL', 'CIMENTO',
#        'FERRO-GUSA E AÇO', 'FERRO-LIGAS', 'MINERAÇÃO E PELOTIZAÇÃO',
#        'NÃO-FERROSOS  E OUTROS DA METALURGIA', 'QUÍMICA',
#        'ALIMENTOS E BEBIDAS', 'TÊXTIL', 'PAPEL E CELULOSE', 'CERÂMICA',
#        'OUTROS', 'CONSUMO NÃO-IDENTIFICADO'],
#       dtype='object')
# Index(['ANO', 'PRODUÇÃO', 'IMPORTAÇÃO', 'EXPORTAÇÃO',
#        'VARIAÇÃO DE ESTOQUES, PERDAS E AJUSTES 2', 'CONSUMO TOTAL',
#        'TRANSFORMAÇÃO 3', 'CONSUMO FINAL', 'CONSUMO FINAL ENERGÉTICO',
#        'SETOR ENERGÉTICO', 'COMERCIAL', 'PÚBLICO', 'AGROPECUÁRIO',
#        'TRANSPORTES', 'RODOVIÁRIO', 'FERROVIÁRIO', 'HIDROVIÁRIO', 'INDUSTRIAL',
#        'CIMENTO', 'FERRO-GUSA E AÇO', 'MINERAÇÃO E PELOTIZAÇÃO', 'QUÍMICA',
#        'ALIMENTOS E BEBIDAS', 'TÊXTIL', 'PAPEL E CELULOSE', 'CERÂMICA',
#        'OUTROS'],
#       dtype='object')
# Index(['ANO', 'PRODUÇÃO', 'IMPORTAÇÃO', 'EXPORTAÇÃO',
#        'VARIAÇÃO DE ESTOQUES, PERDAS E AJUSTES ¹', 'CONSUMO TOTAL',
#        'TRANSFORMAÇÃO', 'CONSUMO FINAL', 'CONSUMO FINAL ENERGÉTICO',
#        'SETOR ENERGÉTICO', 'COMERCIAL', 'PÚBLICO', 'AGROPECUÁRIO',
#        'TRANSPORTES', 'RODOVIÁRIO', 'FERROVIÁRIO', 'HIDROVIÁRIO', 'INDUSTRIAL',
#        'CIMENTO', 'FERRO-GUSA E AÇO', 'MINERAÇÃO E PELOTIZAÇÃO', 'QUÍMICA',
#        'ALIMENTOS E BEBIDAS', 'TÊXTIL', 'PAPEL E CELULOSE', 'CERÂMICA',
#        'OUTROS'],
#       dtype='object')
# Index(['ANO', 'PRODUÇÃO', 'VARIAÇÃO DE ESTOQUES, PERDAS E AJUSTES',
#        'CONSUMO TOTAL', 'TRANSFORMAÇÃO ¹', 'CONSUMO FINAL ²',
#        'CONSUMO FINAL ENERGÉTICO ³', 'COMERCIAL', 'PÚBLICO', 'AGROPECUÁRIO',
#        'TRANSPORTES 4', 'RODOVIÁRIO', 'FERROVIÁRIO', 'INDUSTRIAL'],
#       dtype='object')
# Index(['ANO', 'PRODUÇÃO', 'IMPORTAÇÃO', 'EXPORTAÇÃO',
#        'VARIAÇÃO DE ESTOQUES, PERDAS E AJUSTES ¹', 'CONSUMO TOTAL',
#        'TRANSFORMAÇÃO ²', 'CONSUMO FINAL', 'CONSUMO FINAL ENERGÉTICO',
#        'SETOR ENERGÉTICO', 'COMERCIAL', 'PÚBLICO', 'AGROPECUÁRIO',
#        'TRANSPORTES', 'FERROVIÁRIO', 'HIDROVIÁRIO', 'INDUSTRIAL', 'CIMENTO',
#        'FERRO-GUSA E AÇO', 'FERRO-LIGAS', 'MINERAÇÃO E PELOTIZAÇÃO',
#        'NÃO-FERROSOS  E OUTROS DA METALURGIA', 'QUÍMICA',
#        'ALIMENTOS E BEBIDAS', 'TÊXTIL', 'PAPEL E CELULOSE', 'CERÂMICA',
#        'OUTROS', 'NÃO-IDENTIFICADO'],
#       dtype='object')
# Index(['ANO', 'PRODUÇÃO', 'IMPORTAÇÃO', 'EXPORTAÇÃO',
#        'VARIAÇÃO DE ESTOQUES, PERDAS E AJUSTES ²', 'CONSUMO TOTAL',
#        'CONSUMO FINAL', 'CONSUMO FINAL ENERGÉTICO', 'TRANSPORTES',
#        'RODOVIÁRIO', 'AÉREO'],
#       dtype='object')
# Index(['ANO', 'PRODUÇÃO', 'IMPORTAÇÃO', 'EXPORTAÇÃO',
#        'VARIAÇÃO DE ESTOQUES, PERDAS E AJUSTES ¹', 'CONSUMO TOTAL',
#        'CONSUMO FINAL', 'CONSUMO FINAL ENERGÉTICO', 'SETOR ENERGÉTICO',
#        'RESIDENCIAL', 'COMERCIAL', 'PÚBLICO', 'AGROPECUÁRIO', 'INDUSTRIAL',
#        'FERRO-GUSA E AÇO', 'MINERAÇÃO E PELOTIZAÇÃO',
#        'NÃO-FERROSOS E OUTROS DA METALURGIA', 'QUÍMICA', 'ALIMENTOS E BEBIDAS',
#        'TÊXTIL', 'PAPEL E CELULOSE', 'CERÂMICA', 'OUTROS',
#        'CONSUMO NÃO-IDENTIFICADO'],
#       dtype='object')
# Index(['ANO', 'PRODUÇÃO', 'IMPORTAÇÃO', 'EXPORTAÇÃO',
#        'VARIAÇÃO DE ESTOQUES, PERDAS E AJUSTES ¹', 'CONSUMO TOTAL',
#        'TRANSFORMAÇÃO 2', 'CONSUMO FINAL', 'CONSUMO FINAL NÃO-ENERGÉTICO',
#        'CONSUMO FINAL ENERGÉTICO', 'SETOR ENERGÉTICO', 'INDUSTRIAL',
#        'FERRO-GUSA E AÇO', 'QUÍMICA'],
#       dtype='object')
# Index(['ANO', 'PRODUÇÃO', 'IMPORTAÇÃO',
#        'VARIAÇÃO DE ESTOQUES, PERDAS E AJUSTES', 'CONSUMO TOTAL',
#        'CONSUMO FINAL', 'CONSUMO FINAL ENERGÉTICO', 'SETOR ENERGÉTICO',
#        'INDUSTRIAL', 'CIMENTO', 'FERRO-GUSA E AÇO', 'FERRO-LIGAS',
#        'MINERAÇÃO E PELOTIZAÇÃO', 'NÃO-FERROSOS E OUTROS DA METALURGIA',
#        'OUTRAS INDÚSTRIAS'],
#       dtype='object')
# Index(['ANO', 'PRODUÇÃO', 'IMPORTAÇÃO', 'EXPORTAÇÃO',
#        'VARIAÇÃO DE ESTOQUES, PERDAS E AJUSTES ¹', 'CONSUMO TOTAL',
#        'CONSUMO FINAL', 'CONSUMO FINAL NÃO-ENERGÉTICO',
#        'CONSUMO FINAL ENERGÉTICO', 'SETOR ENERGÉTICO', 'RESIDENCIAL',
#        'COMERCIAL E PÚBLICO', 'AGROPECUÁRIO', 'TRANSPORTES', 'AÉREO',
#        'INDUSTRIAL', 'CIMENTO', 'FERRO-GUSA E AÇO', 'MINERAÇÃO E PELOTIZAÇÃO',
#        'QUÍMICA', 'ALIMENTOS E BEBIDAS', 'TÊXTIL', 'PAPEL E CELULOSE',
#        'CERÂMICA', 'OUTROS'],
#       dtype='object')
# Index(['ANO', 'PRODUÇÃO', 'VARIAÇÃO DE ESTOQUES, PERDAS E AJUSTES',
#        'CONSUMO TOTAL', 'CONSUMO FINAL', 'CONSUMO FINAL ENERGÉTICO',
#        'SETOR ENERGÉTICO', 'RESIDENCIAL', 'COMERCIAL', 'PÚBLICO', 'INDUSTRIAL',
#        'FERRO-GUSA E AÇO', 'NÃO-FERROSOS E OUTROS METALÚRGICOS', 'QUÍMICA',
#        'ALIMENTOS E BEBIDAS', 'TÊXTIL', 'PAPEL E CELULOSE', 'CERÂMICA',
#        'OUTROS'],
#       dtype='object')
# Index(['ANO', 'PRODUÇÃO', 'VARIAÇÃO DE ESTOQUES, PERDAS E AJUSTES',
#        'CONSUMO TOTAL', 'TRANSFORMAÇÃO 1', 'CONSUMO FINAL',
#        'CONSUMO FINAL ENERGÉTICO', 'SETOR ENERGÉTICO', 'INDUSTRIAL',
#        'FERRO-GUSA E AÇO'],
#       dtype='object')
# Index(['ANO', 'PRODUÇÃO', 'CENTRAIS ELÉTRICAS DE SERVIÇO PÚBLICO',
#        'AUTOPRODUTORES', 'IMPORTAÇÃO', 'EXPORTAÇÃO', 'PERDAS', 'CONSUMO TOTAL',
#        'CONSUMO FINAL', 'CONSUMO FINAL ENERGÉTICO', 'SETOR ENERGÉTICO',
#        'RESIDENCIAL', 'COMERCIAL', 'PÚBLICO', 'AGROPECUÁRIO', 'TRANSPORTES',
#        'FERROVIÁRIO', 'INDUSTRIAL', 'CIMENTO', 'FERRO-GUSA E AÇO',
#        'FERRO-LIGAS', 'MINERAÇÃO E PELOTIZAÇÃO',
#        'NÃO-FERROSOS E OUTROS DA METALURGIA', 'QUÍMICA', 'ALIMENTOS E BEBIDAS',
#        'TÊXTIL', 'PAPEL E CELULOSE', 'CERÂMICA', 'OUTROS'],
#       dtype='object')
# Index(['ANO', 'PRODUÇÃO', 'IMPORTAÇÃO', 'EXPORTAÇÃO',
#        'VARIAÇÃO DE ESTOQUES, PERDAS E AJUSTES', 'CONSUMO TOTAL',
#        'CONSUMO FINAL', 'CONSUMO FINAL ENERGÉTICO', 'RESIDENCIAL', 'COMERCIAL',
#        'PÚBLICO', 'AGROPECUÁRIO', 'INDUSTRIAL', 'CIMENTO', 'FERRO-GUSA E AÇO',
#        'FERRO-LIGAS', 'MINERAÇÃO E PELOTIZAÇÃO',
#        'NÃO-FERROSOS E OUTROS DA METALURGIA', 'QUÍMICA', 'TÊXTIL', 'CERÂMICA',
#        'OUTROS'],
#       dtype='object')
# Index(['ANO', 'PRODUÇÃO', 'IMPORTAÇÃO', 'EXPORTAÇÃO',
#        'VARIAÇÃO DE ESTOQUES, PERDAS E AJUSTES', 'CONSUMO TOTAL',
#        'CONSUMO FINAL', 'CONSUMO FINAL NÃO-ENERGÉTICO',
#        'CONSUMO FINAL ENERGÉTICO', 'AGROPECUÁRIO 2', 'TRANSPORTES',
#        'RODOVIÁRIO'],
#       dtype='object')
# Index(['ANO', 'PRODUÇÃO', 'IMPORTAÇÃO', 'EXPORTAÇÃO',
#        'VARIAÇÃO DE ESTOQUES, PERDAS E AJUSTES', 'CONSUMO TOTAL',
#        'CONSUMO FINAL', 'CONSUMO FINAL NÃO-ENERGÉTICO',
#        'CONSUMO FINAL ENERGÉTICO', 'TRANSPORTES', 'RODOVIÁRIO'],
#       dtype='object')
# Index(['ANO', 'PRODUÇÃO', 'IMPORTAÇÃO', 'EXPORTAÇÃO',
#        'VARIAÇÃO DE ESTOQUES, PERDAS E AJUSTES', 'CONSUMO TOTAL',
#        'CONSUMO FINAL', 'CONSUMO FINAL NÃO-ENERGÉTICO',
#        'CONSUMO FINAL ENERGÉTICO', 'AGROPECUÁRIO ¹', 'TRANSPORTES',
#        'RODOVIÁRIO'],
#       dtype='object')
# Index(['ANO', 'PRODUÇÃO', 'IMPORTAÇÃO', 'EXPORTAÇÃO',
#        'VARIAÇÃO DE ESTOQUES, PERDAS E AJUSTES 1', 'CONSUMO TOTAL',
#        'TRANSFORMAÇÃO', 'CONSUMO FINAL', 'CONSUMO FINAL NÃO-ENERGÉTICO',
#        'CONSUMO FINAL ENERGÉTICO', 'SETOR ENERGÉTICO', 'COMERCIAL E PÚBLICO',
#        'TRANSPORTE', 'INDUSTRIAL', 'CIMENTO', 'MINERAÇÃO/PELOTIZAÇÃO',
#        'NÃO-FERROSOS E OUTROS DA METALURGIA', 'QUÍMICA', 'OUTROS',
#        'CONSUMO NÃO-IDENTIFICADO'],
#       dtype='object')
# Index(['ANO', 'PRODUÇÃO', 'VARIAÇÃO DE ESTOQUES, PERDAS E AJUSTES',
#        'CONSUMO TOTAL', 'TRANSFORMAÇÃO 1', 'CONSUMO FINAL',
#        'CONSUMO FINAL NÃO-ENERGÉTICO', 'CONSUMO FINAL ENERGÉTICO',
#        'SETOR  ENERGÉTICO', 'INDUSTRIAL', 'CIMENTO', 'FERRO-GUSA E AÇO'],
#       dtype='object')
# Index(['ANO', 'PRODUÇÃO', 'IMPORTAÇÃO', 'EXPORTAÇÃO',
#        'VARIAÇÃO DE ESTOQUES, PERDAS E AJUSTES 1', 'CONSUMO TOTAL',
#        'TRANSFORMAÇÃO 2', 'CONSUMO FINAL', 'CONSUMO FINAL NÃO-ENERGÉTICO'],
#       dtype='object')

# %% [markdown]
# Depois disso, ainda existem dataframes com anos sem dados, mas é possível usar um índice em comum.
