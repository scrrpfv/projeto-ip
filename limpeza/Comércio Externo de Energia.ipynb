# %%
import pandas as pd

# %%
df = pd.read_excel(r"D:\Users\ehss\Projetoip\projeto-ip\Comércio Externo de Energia.xlsx", header=2).transpose()
df
# Out:
#                                              0                    1    \
# IDENTIFICAÇÃO  DEMANDA TOTAL DE ENERGIA      (a)        CONSUMO FINAL
# 1970                                68096.999677         62107.490054
# 1971                                71193.312659         65371.494839
# 1972                                76298.973578         70005.095932
# 1973                                 83336.08224         76312.296376
# 1974                                88752.829661         81324.392521
# 1975                                92438.882654         84094.672894
# 1976                                97342.101169         89292.273533
# 1977                               101197.526543         92202.483238
# 1978                               106867.149849         97352.629644
# 1979                               113778.736757        103647.512168
# 1980                               115889.018106        104386.204055
# ...

# %%
dict_a = {
    "EVOLUÇÃO DA DEPENDÊNCIA EXTERNA DE ENERGIA": pd.read_excel(r"D:\Users\ehss\Projetoip\projeto-ip\Comércio Externo de Energia.xlsx", header=2, usecols='A:BB', nrows=10).transpose()
    
}

df = dict_a["EVOLUÇÃO DA DEPENDÊNCIA EXTERNA DE ENERGIA"]
df.dropna(axis='columns', inplace=True)
df.rename({"IDENTIFICAÇÃO": "ANO"}, inplace=True)

# %%
new_header = df.iloc[0]
df = df[1:]
df.columns = new_header
df
# Out:
# ANO  DEMANDA TOTAL DE ENERGIA      (a)   CONSUMO FINAL       PERDAS1  \
# 1970                      68096.999677    62107.490054   5989.509623
# 1971                      71193.312659    65371.494839    5821.81782
# 1972                      76298.973578    70005.095932   6293.877646
# 1973                       83336.08224    76312.296376   7023.785864
# 1974                      88752.829661    81324.392521   7428.437139
# 1975                      92438.882654    84094.672894    8344.20976
# 1976                      97342.101169    89292.273533   8049.827635
# 1977                     101197.526543    92202.483238   8995.043305
# 1978                     106867.149849    97352.629644   9514.520205
# 1979                     113778.736757   103647.512168  10131.224589
# 1980                     115889.018106   104386.204055  11502.814051
# 1981                     111563.941876   100660.439623  10903.502253
# 1982                     114141.786307   103194.156363  10947.629944
# ...
